# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exporting csv to Jupyter

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# # 1. Number of males and females participated in the test

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. Parental level of Education grouped

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# # 3. Finding highest Average score based on gender

# %%
grouped_gender = data.groupby("gender")

# %%
grouped_gender.mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
math_mean = data.groupby('gender').mean()
plt.bar(math_mean.index, result['math score'])
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.title('Gender vs Math Average Score', y=1.1)
plt.grid()
plt.show()

# %% [markdown]
# We can clearly see average of male is more.

# %%
reading_mean = data.groupby('gender').mean()
plt.bar(reading_mean.index, result['reading score'])
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.title('Gender vs Reading Average Score', y=1.1)
plt.grid()
plt.show()

# %% [markdown]
# We can clearly see average score of female is more.

# %%
writing_mean = data.groupby('gender').mean()
plt.bar(writing_mean.index, result['writing score'])
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.title('Gender vs Writing Average Score', y=1.1)
plt.grid()
plt.show()

# %% [markdown]
# In this case also, average of female is more.

# %% [markdown]
# # 4. Finding highest Average score based on Test preparation course

# %%
grouped_tpc = data.groupby("test preparation course")

# %%
grouped_tpc.mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# We can clearly see from the data that students with test preparation course on average scored better in all the 3 sections.

# %% [markdown]
# # 5. We can compare the scoring variation by plotting graphs of the marks in subjects based on gender.

# %%
sns.pairplot(data,hue='gender')

# %% [markdown]
# From the above graph we see that, the blue graphs(female) have a more centralised values(dispersion is less) compared to the orange graph(dispersion is more).

# %%
data[['math score','reading score','writing score']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # We know from above that the total number of people are 1000. 25% of 1000 is 250. And we can display the top 250 maths scorers in descending order.

# %%
data.nlargest(250, ['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
